# %% [markdown]
# ## Testing different LLMs to test their performance on extracting information out of Presentation Slides

# %% [markdown]
# ### Before getting started: extract each slide out of an example presentation
# Example Data: [I3D:bio's Training Material for Omero](https://doi.org/10.5281/zenodo.8323588) (Schmidt, C., Bortolomeazzi, M. et al., 2023). For the following code to run, download the pdf in your current folder and name it ['WhatIsOMERO.pdf'](https://zenodo.org/records/8323588/files/202310_GENERAL_OMERO_Material_01_WhatIsOMERO.pdf?download=1) .

# %%
from pdf2image import convert_from_path
from IPython.display import display
from PIL import Image
from pdf_utilities import load_pdf, save_images

slides = load_pdf("test.pdf")
display(slides[0])
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2000x1125 at 0x784319FE7D90>

# %% [markdown]
# ### Option to save those Images on disc:
# - If you want to save the Images in their original size, just ignore the *new_width*  parameter, e.g.
#
#         save_images(".", slides)
#
# - If you want them to be saved in another folder, just add this folder path instead of ".", e.g.
#
#         Windows: save_images(r"C:\Users\username\Documents\Slides", slides)
#
#         macOS: save_images("/Users/username/Documents/Slides", slides)
#
#         Linux: save_images("/home/username/Documents/Slides", slides)

# %%
save_images(".", slides, new_width=400)

# %% [markdown]
# ## 1. [OpenAi GPT-4o](https://github.com/marketplace/models/azure-openai/gpt-4o)

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import (
    SystemMessage,
    UserMessage,
    TextContentItem,
    ImageContentItem,
    ImageUrl,
    ImageDetailLevel,
)
from azure.core.credentials import AzureKeyCredential

token = os.environ["GITHUB_TOKEN"]
endpoint = "https://models.inference.ai.azure.com"
model_name = "gpt-4o"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)
for i in range(1,(len(images)+1)):
    response = client.complete(
        messages=[
            SystemMessage(
                content="You are a professional Data Scientist specializing in Image Data Analysis and Research Data Management."
            ),
            UserMessage(
                content=[
                    TextContentItem(text="Give me a short and precise summary (1-3 whole sentences) of what is displayed or explained in this Slide."),
                    ImageContentItem(
                        image_url=ImageUrl.load(
                            image_file=f"slide{i}.png",
                            image_format="png",
                            detail=ImageDetailLevel.LOW)
                    ),
                ],
            ),
        ],
        model=model_name,
    )
    
    print(f"Slide {i} Summary:\n", response.choices[0].message.content, "\n")
# Out:
# Slide 1 Summary:
#  This slide provides guidelines on using slide templates for I3D:bio OMERO training, including instructions on adjusting slides to fit the institute's style and noting the usage restrictions under a Creative Commons Attribution 4.0 license. It specifies that certain slides are optimized for a 16:9 screen layout and highlights the importance of adapting yellow-marked text with institute-specific information. Additionally, it acknowledges funding support from the Deutsche Forschungsgemeinschaft (DFG).
#
# Slide 2 Summary:
#  The slide provides a disclaimer about the reuse of content, indicating that yellow-marked text should be personalized for the user's institute. It notes that the content might not apply to specific setups of the OMERO installation at the user's location and reflects the authors' opinions, not officially endorsed by the original software or its community.
#
# Slide 3 Summary:
#  The slide introduces a presentation on research data management for bioimage data at a specific institute, focusing on the image data management platform OMERO. It prompts the addition of an author or responsible person and institute logo.
#
# Slide 4 Summary:
#  The slide introduces OMERO, an open-source software for image data management, developed by the Open Microscopy Environment Consortium. It details that OMERO facilitates interaction between user computers, microscope computers, and processing/analysis servers, highlighting installation on central IT servers for storage and handling of imaging data accessible by clients.
#
# Slide 5 Summary:
#  The slide illustrates a transition from isolated data silos in multiple labs, each with its own storage, towards a centralized core facility with integrated storage solutions.
#
# Slide 6 Summary:
#  The slide illustrates a centralized, structured data management system using OMERO, where data from multiple labs is connected to a core facility and IT facility with central storage. Lab personnel are shown capturing and managing microscopy data, which is integrated into a central system.
#
# Slide 7 Summary:
#  The slide provides instructions on accessing OMERO at a specific institute, detailing that it's a centrally provided service by the IT department or core facility. Users can log in via a web address using intranet or VPN, with possible user credential types mentioned.
#
# Slide 8 Summary:
#  The slide outlines the advantages of using OMERO for managing image data. It highlights features such as organizing images with unique IDs, viewing and exploring images with adjustable visualization settings, and analyzing image data with built-in functions. Additionally, it mentions the ability to export data in different formats and share data with colleagues.
#
# Slide 9 Summary:
#  The slide provides contact information for further inquiries, including email addresses for the OMERO administrator and the Light Microscopy Core Facility. It also prompts to add a website link for additional information.

# %% [markdown]
# ## 2. [Llama-3.2-11B-Vision-Instruct](https://github.com/marketplace/models/azureml-meta/Llama-3-2-11B-Vision-Instruct)
#
# Set up the Model and again let it loop through the Images (Slides) and let it summarize their content:

# %%
model_name = "Llama-3.2-11B-Vision-Instruct"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)
for i in range(1,(len(images)+1)):
    response = client.complete(
        messages=[
            SystemMessage(
                content="You are a professional Data Scientist specializing in Image Data Analysis and Research Data Management."
            ),
            UserMessage(
                content=[
                    TextContentItem(text="Give me a short and precise summary (1-3 whole sentences) of what is displayed or explained in this Slide."),
                    ImageContentItem(
                        image_url=ImageUrl.load(
                            image_file=f"slide{i}.png",
                            image_format="png",
                            detail=ImageDetailLevel.LOW)
                    ),
                ],
            ),
        ],
        model=model_name,
    )
    
    print(f"Slide {i} Summary:\n", response.choices[0].message.content, "\n")
# Out:
# Slide 1 Summary:
#  Here is a summary of the image:
#
# This image displays a slide template, which outlines instructions for effectively utilizing the slides. It provides guidance on optimizing the slides for a 16:9 screen presentation layout and offers suggestions for inserting information and using the material. Additionally, it indicates that the content of the material, excluding the logo, is available under a Creative Commons Attribution 4.0 license.
#
# Slide 2 Summary:
#  This slide presents a disclaimer for slides intended to be reused from the i3D:bio project, specifically those with yellow-marked text containing relevant information about the institute. It clarifies that some content may not apply to the specific setup of the OMERO installation at the user's institute and that the content reflects solely the authors' opinions without speaking on behalf of the original software developers or cited community resources.
#
# Slide 3 Summary:
#  This slide is related to the image data management platform OMERO, which is used to manage and store bioimage data. It poses the question, "What is the image data management platform OMERO?" and states that the answer can be found in this slide deck. The slide is part of a presentation on research data management for bioimage data, specifically focusing on OMERO as a tool for managing and analyzing bioimage data.
#
# Slide 4 Summary:
#  This Slide provides an overview of OMERO, an open-source software tool designed for image data management. The tool is accessible both online and offline, allowing users to interact with it via a central server or their own computer. The Slide also features two images that illustrate how OMERO interacts with the client's computer and the Internet Server.
#
# Slide 5 Summary:
#  The slide illustrates the organization of data silos and how they can be managed remotely. It demonstrates how data can be kept in separate facilities, such as central storage, and how access and storage can be managed through Lab 1 to Lab n. Using a remote microscope and storage, users can also interact with the data remotely.
#
# Slide 6 Summary:
#  This slide illustrates the transformation of data management from a centralized, core facility approach to a decentralized, distributed architecture across various laboratories, with an emphasis on the integration of research data management within an IT facility. The core facility is depicted as a centralized hub, while the IT facility is represented as a distributed network, featuring multiple laboratories equipped with computer systems and a microscope. This visual representation highlights the shift towards a more decentralized and collaborative approach to data management in research environments.
#
# Slide 7 Summary:
#  The Slide presents information about the OMERO web portal, which is a service provided by the IT Department/Core Facility of the Add Institute for researchers to access their data. The portal allows users to log in with their user credentials, and once logged in, users can view and manage their data.
#
# **Key Features:**
#
# * **User Credentials:** Users must provide their unique login information to access their data.
# * **Data Management:** The portal enables users to view, manage, and collaborate on their research data.
#
# **Benefits:**
#
# * **Convenient Access:** Users can access their data from anywhere with an internet connection.
# * **Collaboration Tools:** The portal facilitates collaboration among researchers by allowing them to share and work on data together.
#
# By providing a secure and user-friendly platform, the OMERO web portal supports the research community by enabling efficient data management and collaboration.
#
# Slide 8 Summary:
#  This slide highlights the advantages of utilizing OMERO, a software for image data analysis and management. The benefits include organizing original image files in a central storage location, viewing and exploring images with adjustable settings, exporting data to various formats, analyzing data using built-in functions or popular tools like Fiji or QuPath, and sharing data with colleagues.
#
# Slide 9 Summary:
#  This slide is a contact slide that invites the users to provide feedback and additional information about the website, which might be missing or could be improved. There are two email addresses associated with the OMERO and Light Microscopy Core Facility that the users can contact in case of further inquiries.

# %% [markdown]
# ## 3. [Phi-3.5-vision instruct (128k)](https://github.com/marketplace/models/azureml/Phi-3-5-vision-instruct)
# Again, same Set-Up (just a different model name):

# %%
model_name = "Phi-3.5-vision-instruct"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)
for i in range(1,(len(images)+1)):
    response = client.complete(
        messages=[
            SystemMessage(
                content="You are a professional Data Scientist specializing in Image Data Analysis and Research Data Management."
            ),
            UserMessage(
                content=[
                    TextContentItem(text="Give me a short and precise summary (1-3 whole sentences) of what is displayed or explained in this Slide."),
                    ImageContentItem(
                        image_url=ImageUrl.load(
                            image_file=f"slide{i}.png",
                            image_format="png",
                            detail=ImageDetailLevel.LOW)
                    ),
                ],
            ),
        ],
        model=model_name,
    )
    
    print(f"Slide {i} Summary:\n", response.choices[0].message.content, "\n")
# Out:
# Slide 1 Summary:
#   The slide provides instructions on how to use the slide templates for a presentation, including customization for different screen layouts, checking for yellow-marked text, and citation guidelines. It also mentions the licensing of the content under a Creative Commons Attribution 4.0 license and credits the funding source.
#
# Slide 2 Summary:
#   The slide serves as a disclaimer for a presentation, indicating that the slides are intended for reuse with cautionary notes about substituting text and applying specific OMERO installation setup. It also clarifies that the content is based on the authors' opinions and does not represent the software or its developers.
#
# Slide 3 Summary:
#   The slide is a template for a presentation on "Research Data Management for Bioimage Data" at a specific institute, with a focus on explaining the image data management platform OMERO. It includes placeholders for the institute's name, author/responsible person, and logo, along with references and a note on the slide's adaptation.
#
# Slide 4 Summary:
#   The slide presents OMERO, an open-source software for managing image data developed by the Open Microscopy Environment Consortium. It outlines OMERO's connectivity between a client computer and a microscope computer or processing/analysis server, and its installation on an institute or central IT server for handling and storing imaging data, which is accessible through clients.
#
# Slide 5 Summary:
#   The slide illustrates a data silo structure with a central core facility connected to multiple laboratories (Lab 1, Lab 2, Lab n), each with its own storage and possibly with its own microscope. The core facility is linked to a central storage unit. The slide suggests a hierarchical data management system with a potential for centralized data analysis and storage.
#
# Slide 6 Summary:
#   The slide presents a centralized data management system with a core facility connected to an IT facility for storage. There are multiple labs, each with a computer and microscope setup, indicating a structured approach to data handling and analysis.
#
# Slide 7 Summary:
#   The slide provides information about OMERO, a service for researchers, and guides users on how to access the web-address of OMERO, which includes entering a username and password.
#
# Slide 8 Summary:
#   The slide outlines the advantages of using OMERO, including centralized storage, unique image IDs, viewing and annotation features, creating publication-ready figures, data exportation, built-in analysis functions, and the capability to connect with other analysis software.
#
# Slide 9 Summary:
#   The slide provides contact information for an organization, directing to review additional material on their website and listing two email addresses for contact.

# %% [markdown]
# ## 4. [Llama-3.2-90B-Vision-Instruct](https://github.com/marketplace/models/azureml-meta/Llama-3-2-90B-Vision-Instruct)

# %%
model_name = "Llama-3.2-90B-Vision-Instruct"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)
for i in range(1,(len(images)+1)):
    response = client.complete(
        messages=[
            SystemMessage(
                content="You are a professional Data Scientist specializing in Image Data Analysis and Research Data Management."
            ),
            UserMessage(
                content=[
                    TextContentItem(text="Give me a short and precise summary (1-3 whole sentences) of what is displayed or explained in this Slide."),
                    ImageContentItem(
                        image_url=ImageUrl.load(
                            image_file=f"slide{i}.png",
                            image_format="png",
                            detail=ImageDetailLevel.LOW)
                    ),
                ],
            ),
        ],
        model=model_name,
    )
    
    print(f"Slide {i} Summary:\n", response.choices[0].message.content, "\n")
# Out:
# Slide 1 Summary:
#  This Slide provides instructions on how to use and modify the slides for institutional use, ensuring that the material follows the Creative Commons Attribution 4.0 license and includes the necessary citations.
#
# Slide 2 Summary:
#  The slide provides a disclaimer regarding the reuse of slides, stating that they are intended for reuse after substituting yellow-marked text with relevant information at the user's institute. Additionally, it clarifies that some content may not apply to the specific setup of the OMERO installation at the user's institute. The content reflects solely the authors' opinions and does not speak on behalf of the original software, its developers, or other cited community resources.
#
# Slide 3 Summary:
#  The slide is titled "Research Data Management for Bioimage Data at the ADD INSTITUTE HERE" and appears to be a template for a presentation about image data management. The main content of the slide asks, "What is the image data management platform OMERO?" and provides space to add the author or responsible person from the institute.
#
# Slide 4 Summary:
#  The slide describes the OMERO software, an open-source tool for image data management. OMERO is created by the Open Microscopy Environment Consortium (OME) and is accessible via clients installed on an institute or central IT server, allowing users to store and handle imaging data. The software can be accessed remotely through a user computer, microscope computer, or processing/analysis server.
#
# Slide 5 Summary:
#  The slide depicts a data silos scenario where multiple labs are isolated from each other, with each lab having its own storage and microscope. The core facility is also isolated from the labs, and there is a central storage facility that is not connected to any of the labs or the core facility. The image suggests that this isolation is a problem, as indicated by the red X's drawn through the image.
#
# Slide 6 Summary:
#  This slide illustrates a centralized, structured data management system for research data. It features a central IT facility with a core facility and storage, connected to multiple labs (Lab 1, Lab 2, and Lab n) where researchers work on their own microscopes and computers, with each lab having its own unique data analysis workflow. The system appears to be designed to streamline data management and collaboration across different labs and researchers.
#
# Slide 7 Summary:
#  The slide provides instructions on accessing OMERO, a service offered by the IT Department/Core Facility for researchers. It outlines the necessary steps to log in with user credentials and access the web address of OMERO. Additionally, it mentions the use of OMERO for personal, group, collaboration partner, intranet, or virtual private network (VPN) purposes.
#
# Slide 8 Summary:
#  The slide titled "Advantages of using OMERO" presents a concise overview of the benefits associated with utilizing the OMERO platform. The primary advantages highlighted include organizing original image files, viewing and exploring images, exporting image data, analyzing image data, and sharing data with colleagues. These features collectively enhance the efficiency and effectiveness of image data management and analysis within research settings.
#
# Slide 9 Summary:
#  The slide provides instructions for reviewing additional information available on the website and includes contact details for the OMERO administrator and Light Microscopy Core Facility. The contact information includes email addresses for both entities, allowing users to reach out with questions or concerns. Overall, the slide serves as a resource for users seeking further information or support related to the website's content.

# %% [markdown]
# ## 5. [GPT-4o mini](https://github.com/marketplace/models/azure-openai/gpt-4o-mini)

# %%
model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)
for i in range(1,(len(images)+1)):
    response = client.complete(
        messages=[
            SystemMessage(
                content="You are a professional Data Scientist specializing in Image Data Analysis and Research Data Management."
            ),
            UserMessage(
                content=[
                    TextContentItem(text="Give me a short and precise summary (1-3 whole sentences) of what is displayed or explained in this Slide."),
                    ImageContentItem(
                        image_url=ImageUrl.load(
                            image_file=f"slide{i}.png",
                            image_format="png",
                            detail=ImageDetailLevel.LOW)
                    ),
                ],
            ),
        ],
        model=model_name,
    )
    
    print(f"Slide {i} Summary:\n", response.choices[0].message.content, "\n")
# Out:
# Slide 1 Summary:
#  The slide provides instructions on how to use slide templates for I3D:bio OMERO user training, emphasizing the importance of adhering to the specified design and logo, and referring to the "slide master" for formatting. It also highlights that the templates are optimized for a 16:9 aspect ratio and encourages users to customize the content according to their institution's branding. Additionally, it notes the licensing information for the material.
#
# Slide 2 Summary:
#  The slide is a disclaimer indicating that the following content is meant for reuse with relevant modifications highlighted in yellow. It notes that the content may not apply to all setups of the OMERO installation and reflects the authors' opinions, not those of the original software's developers or community resources.
#
# Slide 3 Summary:
#  The slide introduces the concept of the image data management platform OMERO, highlighting its relevance for managing bioimage data at the specified institute. It is part of a presentation on Research Data Management for Bioimage Data.
#
# Slide 4 Summary:
#  The slide explains OMERO, an open-source software developed by the Open Microscopy Environment Consortium (OME) for image data management. It highlights how OMERO connects user and microscope computers to a central server for processing and analysis, enabling efficient storage and handling of imaging data that can be accessed externally by clients.
#
# Slide 5 Summary:
#  The slide illustrates the transition from fragmented data silos in individual labs to a centralized system, emphasizing the need for shared resources and collaboration. It shows multiple labs with their isolated storage and equipment, crossed out to indicate a move towards integration and centralized data management. The central facility is depicted as the core resource for all labs, promoting efficiency and cooperation.
#
# Slide 6 Summary:
#  The slide illustrates a centralized and structured data management system, showing how various labs (Lab 1, Lab 2, and Lab n) connect to a core facility and IT facility for centralized storage. Each lab has access to its own resources, such as computers and microscopes, while contributing to a unified data management framework represented by OMERO.
#
# Slide 7 Summary:
#  The slide outlines the services provided by OMERO at the specified institute, highlighting that researchers can access it using their user credentials. It emphasizes the availability of web access via a specific URL and the option to use OMERO for personal use, collaboration, and remote access through a VPN.
#
# Slide 8 Summary:
#  The slide outlines the advantages of using OMERO, highlighting its ability to organize original image files in a centralized location with unique IDs, facilitate viewing and exploring images with adjustable visualization settings, export image data in various formats, and include built-in analysis functions for data analysis. Additionally, it emphasizes the capability to share data with colleagues.
#
# Slide 9 Summary:
#  The slide provides contact information for two individuals associated with an institute, one being an OMERO administrator and the other from the Light Microscopy Core Facility. It also suggests reviewing additional information available on the institute's website and prompts to add the website link.
